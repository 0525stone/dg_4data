# %% [markdown]
# ## Original image to wide image (12:9)
# ##### 참조 :
# ##### image size : not defined
# ##### 100장이 넘어가면 조금 수정되어야 함(******표시해둠)

# %%
import numpy as np
import sys
import cv2

from matplotlib import pyplot as plt

# %%
# check current working directory 
import os
os.getcwd()
# Out:
# '/Users/johnlee/2019_vanishingpoint/src'

# %%
# example read image
sample = cv2.imread('../../2019_2019_deepguider/data/sample190730/e1.jpg')
#sample = cv2.imread('../../2019_Data/vanishingpoint/sample190730/e1.jpg', cv2.IMREAD_COLOR)
height,width,channel = sample.shape
print(height,'  ',width,'  ',channel)
#cv2.imshow('test',sample)
#cv2.waitKey(0)
#cv2.destroyAllWindows()

plt.imshow(sample)
plt.show()
# Out:
# 2190    3897    3

# %%
2/10
# Out:
# 0.2

# %%
# read image
#num = 0
#tot_num = 0
for i in range (83):
   # print(i)
    chk = int(i/10)
    if (chk==0):
     #   print(i)
        str_ = '00'+str(i)
        filename = '../../2019_deepguider/data/sample190730/'+str_
    if (chk != 0):
     #   print(i)
        str_ = '0'+str(i)
        filename = '../../2019_deepguider/data/sample190730/'+str_
#    *********************100장 넘을경우 if()추가 필요***********************
    image = cv2.imread(filename+'.jpg')
    height, width, channels = image.shape
    height_ = int(width*9/16)
    gap =int((height-height_)/5)
    for j in range(4):
        data = image[:][j*gap:j*gap+height_]
        dataname = '../../2019_deepguider/data/result/'+str_+ str(j)+'.jpg'
        cv2.imwrite(dataname, data)


  #  print(height,' ',width,' ',channels)
#    image = image[][]
